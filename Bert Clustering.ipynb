# %%
from sentence_transformers import SentenceTransformer
from datetime import datetime

import logging
import re

import numpy as np
import pandas as pd
import hdbscan
from sklearn.cluster import AgglomerativeClustering
import umap

import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings(action='ignore')

# %%
model_path = 'distiluse-base-multilingual-cased-v1' # kpfsbert  학습해서 대체 예정.
cluster_mode = 'title'

# %%
# 데이터로딩
DATA_PATH = 'kpfSBERT_Clustering\data/newstrust_20210601_samlple.json'
df = pd.read_json(DATA_PATH, encoding='utf-8')
df.head()
len(df)
# Out:
# 12006

# %%
#sBERT 모델 로딩
model = SentenceTransformer(model_path)

# %%
# 차원축소 -> 연산량을 줄이기 위한 선택영역, 문장->문서로 넘어가면 차원축소 필수 있수도?

# UMAP 차원축소 실행
def umap_process(corpus_embeddings, n_components=5):
    umap_embeddings = umap.UMAP(n_neighbors=15, 
                                n_components=n_components, 
                                metric='cosine').fit_transform(corpus_embeddings)
    return umap_embeddings

# %%
def hdbscan_process(corpus, corpus_embeddings, min_cluster_size=15, min_samples=10, umap=True, n_components=5, method='eom'):
    
    if umap:
        umap_embeddings = umap_process(corpus_embeddings, n_components)
    else:
        umap_embeddings = corpus_embeddings
    
    cluster = hdbscan.HDBSCAN(min_cluster_size=min_cluster_size,
                              min_samples=10,
                              allow_single_cluster=True,
                              metric='euclidean',
                              core_dist_n_jobs=1,# knn_data = Parallel(n_jobs=self.n_jobs, max_nbytes=None) in joblib
                              cluster_selection_method=method).fit(umap_embeddings) #eom leaf

    docs_df = pd.DataFrame(corpus, columns=["Doc"])
    docs_df['Topic'] = cluster.labels_
    docs_df['Doc_ID'] = range(len(docs_df))
    docs_per_topic = docs_df.groupby(['Topic'], as_index = False).agg({'Doc': ' '.join})
    
    return docs_df, docs_per_topic

# %%
# 카테고리별 클러스터링
start = datetime.now()
print('작업 시작시간 : ', start)
previous = start
bt_prev = start

tot_df = pd.DataFrame()

print(' processing start... with cluster_mode :', cluster_mode)

category = df.category.unique()

df_category = []
for categ in category:
    df_category.append(df[df.category==categ])
cnt = 0
rslt = []
topics = []
#순환하며 데이터 만들어 df에 고쳐보자
for idx, dt in enumerate(df_category):

    corpus = dt[cluster_mode].values.tolist()
    # '[보통공통된꼭지제목]' 형태를 제거해서 클러스터링시 품질을 높인다.
    for i, cp in enumerate(corpus):
        corpus[i] = re.sub(r'\[(.*?)\]', '', cp)
#     print(corpus[:10])
    corpus_embeddings = model.encode(corpus, show_progress_bar=True)

    docs_df, docs_per_topic = hdbscan_process(corpus, corpus_embeddings,
                                               umap=False, n_components=15, #연산량 줄이기 위해 umap 사용시 True 
                                               method='leaf',
                                               min_cluster_size=5,
                                               min_samples=30,
                                               )
    cnt += len(docs_df)

    rslt.append(docs_df)
    topics.append(docs_per_topic)
    dt['cluster'] = docs_df['Topic'].values.tolist()
    tot_df = pd.concat([tot_df,dt])

    bt = datetime.now()
    print(len(docs_df), 'docs,', len(docs_per_topic)-1 ,'clusters in', category[idx], ', 소요시간 :', bt - bt_prev)
    bt_prev = bt
now = datetime.now()
print(' Total docs :', cnt,'in', len(rslt), 'Categories', ', 소요시간 :', now - previous)
previous = now

#cluster update    

df['cluster'] = tot_df['cluster'].astype(str)
    
end = datetime.now()
print('작업 종료시간 : ', end, ', 총 소요시간 :', end - start)
# Out:
# 작업 시작시간 :  2022-08-05 11:12:16.137773
#  processing start... with cluster_mode : title
# Batches:   0%|          | 0/26 [00:00<?, ?it/s]
# 819 docs, 8 clusters in IT 과학 , 소요시간 : 0:00:42.184294
# Batches:   0%|          | 0/84 [00:00<?, ?it/s]
# 2662 docs, 19 clusters in 경제 , 소요시간 : 0:02:07.924729
# Batches:   0%|          | 0/22 [00:00<?, ?it/s]
# 692 docs, 7 clusters in 국제 , 소요시간 : 0:00:33.975413
# Batches:   0%|          | 0/149 [00:00<?, ?it/s]
# 4751 docs, 28 clusters in 사회 , 소요시간 : 0:03:53.708651
# Batches:   0%|          | 0/18 [00:00<?, ?it/s]
# 562 docs, 2 clusters in 연예 , 소요시간 : 0:00:28.589699
# Batches:   0%|          | 0/20 [00:00<?, ?it/s]
# 637 docs, 3 clusters in 문화 예술 , 소요시간 : 0:00:29.405428
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# 91 docs, 0 clusters in 사설·칼럼 , 소요시간 : 0:00:03.710594
# Batches:   0%|          | 0/38 [00:00<?, ?it/s]
# 1188 docs, 8 clusters in 정치 , 소요시간 : 0:01:00.641535
# Batches:   0%|          | 0/9 [00:00<?, ?it/s]
# 259 docs, 2 clusters in 교육 , 소요시간 : 0:00:11.782991
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# 79 docs, 0 clusters in 라이프스타일 , 소요시간 : 0:00:03.947092
# Batches:   0%|          | 0/9 [00:00<?, ?it/s]
# 266 docs, 2 clusters in 스포츠 , 소요시간 : 0:00:11.965528
#  Total docs : 12006 in 11 Categories , 소요시간 : 0:09:47.836986
# 작업 종료시간 :  2022-08-05 11:22:03.994390 , 총 소요시간 : 0:09:47.856617

# %%
categ = '사회'
condition = (df.category == categ) & (df.cluster == '-1') # 조건식 작성b

# %%
test = df[condition]
print(len(test))
test.title.values.tolist()
# Out:
# 4343
# ['기보?창원산업진흥원, 기술이전・기술금융 지원 업무협약 체결',
#  "용인시, 시청에서 일회용품 안쓰는 'One-Zero day' 운영",
#  '생산성본부・가평군, 소상공인 경영환경개선 지원 나선다',
#  "정부, '지방소멸 위기' 대응 위한 기반 마련…행정・재정 지원 추진",
#  '중기부, 지역가치 창업가 협업지원 추진',
#  '동반위-국민은행, 제3회 동반성장 대기업 협력사 PR챌린지 개최',
#  "농협은행, 10일 '생애주기별 자산관리 웹세미나' 개최",
#  '[부음]한홍수(포항대 총장)씨 장인상',
#  "광주경제고용진흥원, 생활 속 일회용품 줄이기 '고고 챌린지' 참여",
#  '화학연, 탄소중립 위한 친환경 산업가스 개발 업무 협약 2건 체결',
#  "당근마켓 '내 근처'에서 만나는 청소연구소…청소 예약・결제 한 번에",
#  "SK렌터카, 제주지점 공항 인근으로 이전...셔틀 거리 '10→2분'",
#  "야놀자, 지역경제 활성화 위한 '전국 1주' 프로젝트 진행",
#  '[인사]NEWS 더원',
#  "NH농협생명, '무배당 두개만묻는NH건강보험(갱신형)' 출시",
#  '[인사]ABL생명',
#  'DTG 분석해 민자도로 맞춤형 안전대책 수립',
#  '[부음]조선(부산일보 상임감사)씨 부친상',
#  '동서식품, 맥심 커피믹스 종이 손잡이 도입...플라스틱 저감 동참',
#  "광주시, 'K-Pop 스타의거리' 콘텐츠 개발한다…대표 랜드마크 마케팅",
#  "환경부 내 '기후탄소정책실' '물관리정책실' 신설",
#  '[부음]안재영(ubc울산방송국 부장)씨 부친상',
#  '[부음]윤동섭(연세의료원장)씨 장인상',
#  "신세계아이앤씨, 청소년 해커톤 대회 '헬로 뉴( ) 월드' 참가자 모집",
#  '[부음]이선영(SR 경영지원실장) 씨 장인상',
#  '전남테크노파크, 광양만권경제자유구역 비즈니스 역량강화 참여기업 모집',
#  '[인사]기상청',
#  "철도연, '스크롤 공기압축기 상용화기술' 이전...철도차량・도시버스 제동장치 고장",
#  '공공폐자원관리시설, 설치지역 주민과 운영이익 나눈다',
#  "경동나비엔 '키친플러스' 환기시스템 시장에 새 바람",
#  'KT, 경기도와 현장 맞춤 미래기술인력 양성',
#  "생명연, '제12회 전국 고등학생 바이오안전성・바이오산업 토론대회' 개최",
#  '광주상의, 전자입찰 컨설팅 참여기업 18개사 선착순 모집',
#  "광주시, 4개 전문기업과 '광주형 AI 비즈니스' 92~95번째 업무협약",
#  '[인사]뉴스1',
#  '[인사]광남일보',
#  "NS홈쇼핑, 100년 전통의 맛 '백년가게 부산 내호밀면' 단독 출시",
#  "소프라노 조수미씨 '2021광주디자인비엔날레' 명예홍보대사 위촉",
#  '[부음]임화섭(연합뉴스 기자)씨 조모상',
#  "대전시, 도시재생 예측모델 개발...'빅데이터 정책 지원 플랫폼 서비스' 제공",
#  '한국기업데이터, 코로나19 접종 임직원 대상 백신휴가제도 도입',
#  '[인사]ABL생명',
#  '인천공항 도착한 모더나 백신 첫 도입물량',
#  '국가철도공단-한국철도공사, 민간기업 신호기술 교류',
#  '홈플러스, 유기농데이 기획전 행사',
#  '목포대 LINC+사업단, 전남형 상생일자리 실무추진단 협의회 개최',
#  '광주그린카진흥원-한국산업기술시험원, 친환경 자동차・부품기업 경쟁력 강화 지원 MOU',
#  'LG유플러스-한국폴리텍VII대학, 스마트팩토리 산업활성화 협력',
#  "LG전자 '탈플라스틱' 협약 1만여톤 감축",
#  '방송영상독립제작사 신고 의무화・・・문화산업진흥 기본법 시행령 9일 시행',
#  '[이슈톡] 해운대·송정해수욕장 오늘 개장',
#  '"살면서 겪을 수 있는 일"…약혼자도 압박',
#  '[뉴스 열어보기] 평양이 왜 거기서 나와',
#  '양도세 올려 압박했지만…매도 대신 증여 선택',
#  "오늘부터 접종자 '8명+α' 가능…혜택 적용",
#  '혼자 출산 뒤 방치 살해…"키울 일 막막해서"',
#  '1부 오늘의 주요뉴스',
#  '[날씨] 오전에 비 대부분 그쳐…서울 25도 등 초여름 날씨',
#  "직접 '맞잡은 손'에 눈물 '왈칵'…접종자 일상 회복 첫날",
#  '농촌 총각과 \'베트남 유학생\' 연결?…"인종차별적 인식"',
#  '文, 오늘 김오수 검찰총장에 임명장…과제는?',
#  '백신 접종자, 인원 제한 없이 가족 모임 가능',
#  'LH 전·현직 성남 재개발 투기 의혹…40채 매입',
#  '[날씨] 오후까지 산발적인 빗방울…공기는 내내 깨끗',
#  '"일가족 살해 계획 없었다"…유족들 "반성하는 척" 반발',
#  '\'유령 수술\' 8년 후유증…"원장 다시 수사해달라"',
#  "[단독] '극단 선택' 암시 공군본부에도 보고 됐지만…오히려 '압박'",
#  '처벌 강화됐어도…만취 승객이 또 택시기사 무차별 폭행',
#  '김오수 검찰총장 취임…"\'국민 중심의 검찰\'로 탈바꿈"',
#  '[날씨] 대체로 선선한 날씨…내일 전국 기온 크게 상승',
#  '신규 확진 459명…접종자 일상 회복 시작',
#  '다크웹·가상자산 이용 마약 거래…521명 검거',
#  '다크웹·가상자산 이용 마약 거래…521명 검거',
#  '혼인신고 후 세상 떠난 여군…"용서 못 해요"',
#  '"\'성추행 사건\' 엄정 수사"…국민청원 하루 만에 20만 명',
#  "아시아계 여성에 다짜고짜 주먹질…뉴욕서 또 '증오 범죄'",
#  '서욱 "공군 \'성추행 의혹 사건\' 엄정 수사"',
#  '국방부 "피해자 보호 못했다"…합수단 구성',
#  '"안 갔다" 잡아뗐지만…\'룸살롱 검사\' 3명 징계',
#  '오늘 신규 확진자 400명대 중후반 예상',
#  '한라산 암벽 일부 붕괴…"자연 풍화작용 추정"',
#  "경찰, '박덕흠 특혜수주 의혹' 첫 강제수사",
#  '오늘 임명장 받는 김오수 검찰총장…과제는?',
#  "얀센 '선착순' 예약 접수…10일부터 접종",
#  "얀센 '선착순' 예약 접수…한때 접속자 몰려",
#  "얀센 '선착순' 예약 접수…한때 접속자 몰려",
#  "시운전 군함서 포탄 발사…여객선 주변에 '펑펑' 물기둥",
#  '가짜 코인에 15억 날려…가상화폐 사기단 적발',
#  '"피해자 2명 더 있어…수사 결과 공개해야"',
#  '클로징',
#  '與 "2차 추경 시급"… 野 "빚 잔치로 치적"',
#  '"윤석열, \'내 장모, 누구한테 피해 준 적 없다\'"',
#  '[날씨] 대구 한낮 기온 30도 안팎…미세먼지 농도 좋음에서 보통',
#  '특수고용직 7월부터 고용보험…보험료 절반씩',
#  '중학생에게 AZ백신 주사…"의료진으로 착각"',
#  "'조국의 시간'에 엇갈린 입장…여권 내 파장",
#  "'얀센' 하루 만에 예약 끝…모더나까지 '4종 백신' 체제",
#  '네이버 "문제 임원·조직장 인사조치 하겠다"',
#  '대구시 "화이자 3천만명분 확보"…정부 "정품 검증해야"',
#  '9일 연속 근무한 뒤 끝내 사망…"유족 정직원 시켜주겠다"',
#  '국민의힘 입당 저울질?…"장모, 10원 한 장 피해 안 줘"',
#  '뉴스데스크 클로징',
#  '미열에 가래 증상 있다 하니…병원들 응급환자 손사래',
#  '지역중심시대 부울경 기업을 응원하다! <8-상> 경성산업',
#  '가야대 청소년 중독 관리자 배출',
#  '[뉴스 분석] 한참 늦은 부산시-kt 협상…탈부산 명분만 주나',
#  '부산조선기자재조합, 강현철 부산노동청장과 간담회',
#  '오동윤 교수 중기연구원장 취임',
#  '기술보증기금, 창원산업진흥원과 업무협약 체결',
#  '장전동 ‘휴먼파크장전지역주택조합’ 사업 신속 추진 눈길',
#  '과학상 양해식 교수 “질병감염 알려주는 바이오센서 개발 성과 뿌듯”',
#  '방역 접점 찾은 영화의전당, 야외상영회 2일부터 연다',
#  '르노삼성 노조 현장 복귀',
#  '대한민국 광복회 부산북구지회, 부산 북구에 ‘진관사 태극기’ 복원품 전달',
#  '부산시새마을회, ‘2021 상반기 다시 입을 수 있는 옷 모으기 경진대회’ 개최',
#  '사제 총 만들어 판 일당 적발…한국도 총기 안전지대 아니다',
#  '백발되어 나타난 오거돈 “피해자에 거듭 죄송”',
#  '대저공공주택 건설 첫 발…전략환경영향평가 절차 돌입',
#  '백신접종 예약 우수마을에 총 10억',
#  '부산과학기술상 과학상 양해식·공학상 하만영',
#  "구시영의 '사람&세상' <12> 극한기후 세계적 학자 하경자 부산대 교수",
#  '거제시-지심도 주민 상생, 명품섬 만들기 시동 건다',
#  '고령자 면허반납 당일 처리 가능…안전운전 환경·제도 정착에 박차',
#  '정부 ‘인구감소지역’ 하반기 첫 지정',
#  '대하 등 부산·경남 4곳, 수소전문기업 첫 선정',
#  '[뉴스 분석] 새로울 것도, 우선순위도 없는 ‘부산형 뉴딜’',
#  '㈜경성리츠, 초록우산 어린이재단 부산아동옹호센터에 후원금 전달',
#  '요양병원 이제 한숨 돌렸는데…접촉면회 재개에 불안감',
#  '동의과학대·힘내라병원 지정병원 협약',
#  '공무원연금공단 소속 부산상록브라보청춘봉사단, 안전한바퀴 활동 실시',
#  '뜬구름 잡는 부산 스마트물류, 거침없는 울산·경남 해상풍력',
#  '“김해 하수시설에 IT 접목…사고 즉각 대처 가능”',
#  '[부음] 조진영 씨 별세, 선(부산일보 상임감사) 씨 부친상',
#  '오늘의 날씨- 2021년 6월 2일',
#  '부산지방보훈청, 부산중부경찰서와 업무협약 체결',
#  '부산무용협회 회장에 김갑용 춤과사람대표',
#  '공학상 하만영 교수 “글로벌 산학협력 경험 동남권 기업과 공유할 것”',
#  '㈜경성리츠, 초록우산 어린이재단 부산아동옹호센터에 후원금 전달 外',
#  '김해 삼방시장 일대 간판, 새 디자인 입었네',
#  '마늘텃밭 한쪽 양귀비 수백 포기…약으로 쓴다며 70대 ‘몰래 재배’',
#  '[단독] 부하에 부적절한 성적행위 강요한 조폭',
#  '[르포] ‘밤 11시까지 영업’ 시민 잘 몰라…상인 “주말 장사 기대”',
#  '기계설비업계, 부산시 건축설비팀 무산에 반발',
#  '양산복합문화관 내달 착공…4층 규모 324억 원 투입',
#  '백신접종자 가족모임 제한 해제',
#  '영동군, 군민과의 소중한 약속 잘 지키네',
#  '충주시 신은진 주무관, 5월 행복배달통 주인공으로 선정',
#  '옥천군 점자민원업무 안내책자 제작',
#  '제천시, 농업가치 기반 바른 식생활 교육 실시',
#  '한국교통대, 소외계층 위한 생활과학교실 운영',
#  '청주시 균형발전분야 13개 핵심공약 추진 순조',
#  '휴마시스㈜ 코로나 자가진단키트 기탁',
#  '청주청원경찰서 현장대응능력 강화 FTX 훈련',
#  '<코로나종합>선제 검사 받은 50대 확진',
#  '"깨끗하고 안전한 물 공급 공동 노력"',
#  '이용재 "중앙정부와 지자체 간 가교역할에 충실"',
#  '세종 5개 시내버스 노선 운행 모두 정상화',
#  '인물 동정 (6월 2일)',
#  '영동 정수중, 초등학생과 함께하는 진로과학행사 개최',
#  '음성군, 2021 음성전국사이클대회 개최',
#  '중부내륙선철도 충주~이천 구간 12월 개통',
#  '"음성 생활폐기물 대행업체 엄중 수사하라"',
#  '<날씨>2일 충북 대체로 맑고 가끔 구름 많아',
#  '친환경 찾는 청주 시민 늘었다',
#  '충주경찰, 건국대사거리~달천대교 상습정체 해소',
#  '영동군, 상반기 상하수도 체납요금 징수 나서',
#  "충주시의회, '댐 상류 물자치포럼' 개최",
#  "옥천군, 지역 현안사업 해결 위해 '발품 행정'",
#  '한국주택금융공사 충북지사, 제천시노인종합복지관 후원',
#  '바르게살기운동제천시협의회, 태극기 달기 협약',
#  '단양소방서, 대한민국 안전대상 공모',
#  "충주교육지원청, 현장직업체험형 '진로·직업체험의 날' 운영",
#  '충북보과대 학생 홍보대사 8명 선발',
#  '이재숙 한국여성소비자연합 충북지회장, 소비촉진운동 챌린지 동참',
#  "충북도문화재연구원, '동행 문화유산' 수어 해설영상 제작·배포",
#  'SK에코플랜트, 클렌코 인수 추진… 지역사회 관심',
#  "이노비즈협회 충북지회 '충청권 광역철도 청주 도심 통과' 촉구",
#  '충북청년광장 6기 출범… 정책발굴 활동 본격화',
#  '강동대, 2년 연속 사회맞춤형 산학협력',
#  '여름철 성수기 대비 야영장 합동점검',
#  '자율주행 트랙터 오창·옥산 뜰 누빈다',
#  '청주 모충동 자원봉사대, 보양 삼계탕 나눔 봉사',
#  '청주 이끌림치과, 라면 42상자 후원',
#  '도로공사, 1일부터 고속도로 화물차에 생수얼음 무료 제공',
#  '임택수 청주부시장, 물놀이 안전시설 현장점검',
#  '청주 상당구, 면지역 축산물 판매업소 위생점검',
#  '아침을 여는 詩 - 황사',
#  '진천군, 폐업(예정) 소상공인 지원 신청·접수',
#  '[인사] 충북도립대',
#  '베스티안병원 CPR 훈련',
#  '보은 관광중심지 법주사→말티재 이동',
#  '영동군, 영동 발전을 위한 국민제안 연장 공모',
#  '항상 웃는 영동군청 직원들, 소통하고 공감하는 행복민원실 운영',
#  "영동읍 사랑나눔 행복나눔 릴레이 2호 기부천사 '노병주 씨'",
#  "괴산군, 이달의 친절공무원 '김지연' 주무관 선정",
#  '음성군, 산사태 대책상황실 운영',
#  '증평군 보훈회관 개관',
#  '제천시 영서동 새마을남녀협, 방역소독 지원',
#  "제천 왕미초, 세계 금연의 날 '흡연예방 캠페인' 펼쳐",
#  '진천군, 무허가 축사 적법화율 91%',
#  "충북지식재산센터, 7월 2일까지 'IP나래 지원사업' 참여기업 모집",
#  '충북도, 하계 학생아르바이트 참여자 모집',
#  "충주시, 코로나 잔여 백신 '당일 예약시스템' 안내",
#  '충주시, 시청 내 분신 소동 민원인 오해로 밝혀져',
#  '진천 20대 외국인 1명 추가 확진…누적 334명',
#  "영동군, 66회 현충일 맞아 '나라사랑 태극기 달기 운동'",
#  '충주자원봉사센터, 해양오염 방지 캠페인 활동',
#  '제천시노인종합복지관, 2021 교통안전 베테랑 교실 수료식 개최',
#  '단양 소백산자연휴양림, 안심 휴양지로 인기',
#  '보은 산외주민자치위 일손봉사',
#  '충북 과수화상병 확진농가 112곳 달해',
#  '음성 김덕영 관장, 이휘현 청소년지도사…국무총리 표창, 여성가족부장관상 수상',
#  '장애인 복지 증진·지원 방안 모색',
#  '코로나19 직격탄 맞은 자영업자·농업인 지원 늘린다',
#  '오송바이오밸리 성공 비결 직접 보러 왔다',
#  '영동군, 도내 최초 일반세대 가스타이머콕 보급사업 추진',
#  '충주 창업농부, 라이브커머스 도전',
#  '"집중호우 피해 재발 막자"…우기 전 재해복구사업 한창',
#  '청주 도심 통과 광역철도 염원 촛불로 이어져',
#  '청주 내수농협, 여성조직도 농촌일손돕기 동참',
#  '청주시의회, 영농철 맞이 농촌 일손 돕기',
#  '청주상당경찰서 서희철 경위 등 4명 승진',
#  '옥천 죽향초, 옥천 발명 꿈나무대회 개최',
#  '행사 알림(6월 2일)',
#  '제천소방서, 지역자율방재단 대원 물놀이 안전교육',
#  '충주교육지원청, 2분기 충주-청렴人 표창',
#  '옥천군, 도로 경관조성으로 상권 활성화 나선다',
#  '진천군 덕산건강생활지원센터 운영 시작',
#  '충주미덕중 학생회, 미덕 MBA 농구 한마당 개최',
#  '"청주 형석중 정도운군에게 건강의 날개 달아주세요"',
#  '임용환 충북경찰청장 영동署 방문 치안행정 간담회 개최',
#  "충북도립대, 지역 상생 위한 메이커스페이스센터 구축 '머리맞대'",
#  '보은농협 영농자재센터 개장',
#  '단양군, 전통시장 소화기 교체·보급사업 추진',
#  '충주소방서 서충주119안전센터 근무 돌입',
#  "괴산군노인복지관, '찾아가는 실버 건강 대학' 운영",
#  '국립세종도서관, 15일부터 독서문화프로그램 특강',
#  '순천향대 RGB CAMPUS 사업단, 산학연 협력 허브 공간 구축',
#  '예민사회…‘코로나 앵그리’ 범죄 잇따라',
#  '“울지마, 여보”… 470일만에 잡은 아내의 손',
#  '선박화재로 플라스틱 유출…스리랑카, 최악의 환경재앙',
#  '영진전문大 ‘마이스터대 사업’선정… 4차 산업혁명 인재양성 탄력',
#  '김용인 재향경우회 제23대 중앙회장 공식 취임',
#  '<시평>검찰 정신 배신하는 정권의 부역자들',
#  '신호등·표지판 미비… 아이들 등하굣길 ‘아슬아슬’',
#  '“아동학대 예방”… 현대차 ‘아이케어카’ 기부',
#  '제일모직 기념관~삼성상회~호암 고택… ‘경제 신화’를 따라 걷다',
#  '“한국서도 노벨화학상 수상자 나오길”… 장학사업 꽃 피운다',
#  '경기 시흥 지식산업센터 ‘시흥매화 센트럴 M플렉스’ 분양',
#  '문 대통령 COP28 유치 선언에 남해안남중권 “환영·지지”',
#  '김봉진 우아한형제들 의장의 우아한 기부',
#  '소프라노 조수미 씨, 2021광주디자인비엔날레 명예홍보대사로',
#  '<부고>공영수씨 별세 外',
#  '구로구, ‘참좋은 지방자치 정책대회’ 협의회장상 수상',
#  '“아동학대 근절·안전한 보육”…‘은평형’ 열린어린이집 추진',
#  '인도에 2억규모 의료장비 후원',
#  '유희경 전통복식 1호박사 영면',
#  '‘급식불만’ 폭주에 두 손 든 국방부',
#  '공공폐자원관리시설 설치 시 주민에 최대 20% 수익 배분',
#  '‘성추행 피해 부사관 혼인신고 날 사망’사건 파문 확산…“공군총장 직접 사과” 목소리도',
#  '충남 서산민항 유치, 국회서 ‘군불’',
#  '검찰, 의료법 위반 혐의로 기소된 윤석열 장모 징역 3년 구형',
#  '“코로나 백신 접종한 어르신들 오세요”… 중구, 경로당 온종일 개방',
#  '<포럼>위법성 짚이는 ‘검찰 개악’ 조치들',
#  '동대문구 ‘지켜줘 홈즈’ 사업…여성1인 가구 안전장비 지급',
#  '중랑구, 청소년 전용 공간 ‘딩가동 2번지’ 2호점 오픈',
#  '송파구, 신천맛골~올림픽공원 활성화 용역 추진',
#  '단체급식 위생관리 대폭 강화… 현대그린푸드, 이른 더위 대응',
#  '부산은행 소상공인 자금지원 협약',
#  '현대百, 환경경영시스템 인증',
#  '경찰, 손정민 친구 폰 포렌식… “의심 단서 발견 못해”',
#  '박준희 관악구청장, 매니페스토실천본부 선정 최우수 기초단체장',
#  '美서 총기부품 위장 수입… 총기 제작·판매 7명 적발',
#  '‘권력수사 방탄총장’ 김오수, 文 임기말 ‘중립성 시험대’ 올랐다',
#  '환경부, 기후탄소정책실·물관리정책실 신설',
#  '사위들의 반란 통했다…법원 “종중 재산, 딸도 아들과 같은 몫 줘야”',
#  '374만명에 ‘접종 인센티브’… ‘백신 4종 세트’ 본격 가동',
#  '내년 동네의원 초진비 490원 인상',
#  '‘4차 재난지원금’ 8개 사업중 7개 실집행률 ‘제로’',
#  '피의자 김오수 ‘김학의 사건’ 무혐의 될듯… 이광철은 대검차장이 기소여부 판단',
#  '차기 서울중앙지검장 유력 거론… 심재철·김관정 ‘이해충돌’ 논란',
#  '심사평가원, 국내 의료행위 분류 용어 표준화 기틀 마련',
#  '김재종 옥천군수, 공약 이행률 80.8% 순항',
#  '세종시, 3기 여성친화도시 시민참여단 모집',
#  "옥천군 '청춘 먹자골목' 조성 본격 추진",
#  "대전시, '전동 킥보드 공유 서비스' 시민의견 듣는다",
#  "주택금융공사 충북지사, 제천노인복지관에 성금 '기탁'",
#  "제천고, '유형·전략별 학습코칭' 운영",
#  "농협네트웍스, '사랑의 집고치기'",
#  '코로나 19, 금연이 더욱 중요한 이유',
#  "내포문화숲길 '국가숲길 승격' 도전",
#  '가업 잇는 소상공인 경영 안정 돕는다',
#  "예산군, 상반기 깨끗한 축산농장 지정평가 '전국 최대' 32개소 지정",
#  '화단에 예쁜국화 심으세요!',
#  '임업인 바우처 1차 대상 2008명 확정',
#  '예산군, 과수화상병 예방 위한 긴급 방제약제 지원 나서다!',
#  '보은군 산외면 주민자치위원회, 생산적 일손봉사 추진',
#  '진천군의회, 청렴의식 확립 교육 성료',
#  "태안군 ,황토호박고구마 '명품화' 나서",
#  '청주 운호고 학생들 마스크 분리배출 홍보 영상 제작',
#  '음성 대소면, 복지사각지대 대상자 주거환경개선 서비스 지원',
#  '음성군, 음성 전국사이클대회 열려',
#  '천안, 학교주변과 유해업소 밀집지역 지도점검',
#  "금산군, 코로나 19 자가격리자 심리방역키트 '새 구성'",
#  '음성 금왕읍, 지방세 소액체납액 정리 나서',
#  '[동정] 이상천 제천시장',
#  'LG, 지역 복지시설에 태양광 설비 기증',
#  '충남대병원, 부정부패 없는 공정한 조직문화 조성',
#  '연암대 2021 KKC 어질리티 챔피언쉽 학생부 최우수 핸들리상 수상 화제',
#  '당진시 4-H연합회, 공동과제포 모내기 행사 성료',
#  '충북도-전경련, 중기 온라인 경영자문상담회 참여기업 모집',
#  '충북도-11개시·군-금강환경청-수자원공사 업무협약',
#  '충북도, 스마트빌리지 확산 공모사업 선정',
#  '한범덕 청주시장, 국가유공자의 집 명패 달기',
#  "한상기 전 태안군수 2022년 지방선거 '태안군수'출마 선언",
#  '괴산군 마을김치체험위원회, 브로콜리순김치 150박스 기탁',
#  '죽향초, 옥천 발명 꿈나무대회 개최',
#  '청주상당경찰서, 승진 임용식 개최',
#  'IP나래 지원사업, 참여기업 모집',
#  '진천교육청-문백 통산마을, 자매결연',
#  '당진시, 유흥·다방업소 등 불법퇴폐영업 근절에 나서',
#  '음성군의회, 정례의원 간담회 열어',
#  "당진소방서, 인명구조사 취득 훈련에 '구슬땀'",
#  '민주평통 청양군협의회, 평화,종전 선언 위한 걷기 행사',
#  '영동군, 군민과의 소중한 약속 잘 지키네!',
#  "영동군, 66회 현충일 맞아 '나라사랑 태극기 달기 운동'",
#  '청양소방서, 아파트 화재 시 피난방법 홍보 나서',
#  "태안군, 찾아가는 전입서비스 '큰 호응'",
#  "지속가능한 '홍성형 농촌모델' 국가균형발전위원장 상 수상",
#  '한밭대, 황선효 교수 대학공헌 업적 기념 동판 헌정',
#  "단양 버섯모양 '복자기 가로수', 눈길",
#  '청주시, 성평등 학습회 운영',
#  "단양군, 지역 맛집 소개하는 '맛 지도' 제작",
#  '옥천군, 점자 민원업무 안내책자 제작',
#  '계룡시, 사계고택서 우수자원봉사자 문화탐방 가져',
#  '계룡소방서, 소방시설공사 분리발주 이행실태 점검 나서',
#  '음성군, 산사태 대책상황실 운영',
#  '산림청, 산림보호지역 불법 벌채행위 단속',
#  "'널뛰기 기온'에… 옥천 농작물 냉해 피해 심각",
#  "충북도립대 메이커스페이스센터 구축 '머리 맞대'",
#  '[행사] 6월 2일 천안시',
#  '고덕중학교, 청렴한 학교 만들기에 학부모와 환경동아리 학생들이 나섰다',
#  "태안군, 태안읍 생활폐기물 청소 군 직영 '큰 호응'",
#  '진천군, 무허가 축사 적법화 후속조치 나서',
#  '증평군, 보훈가족 새로운 보금자리 마련',
#  '천안, 도로변 수종갱신 사업 마무리',
#  '천안, 농업인수당 1차분 지급',
#  '[동정] 박상돈 천안시장',
#  '예산군, 봉산면 기초생활거점조성사업 본격 출발',
#  '예산군, 코로나19 확산 예방 위한 장기요양시설 방역수칙 이행 점검',
#  '보은군, 2021년 하계 학생근로활동 모집',
#  '〔동정〕 정상혁 보은군수',
#  "'충남지방자치분권 포럼' 창립…자치분권시대 선도",
#  '예산군, "어르신들의 가장 아름다운 모습을 담아드립니다!"',
#  '보은농협, 영농자재센터 개장',
#  "서산시, 성연면 농업단체 100만원 상당'해열진통제' 기탁",
#  '올리비아로렌 청주 수곡점, 이웃돕기 동참',
#  '유성구, 민원창구에 양방향 마이크 설치',
#  '진천군, 코로나19 폐업 소상공인 지원',
#  '충남대, 국가직 지역인재 7급 7명 배출',
#  '베스티안병원, 코로나19 상황 CPR 훈련 실시',
#  '충북시민단체 "음성군 폐기물업체 비리 엄정 수사하라"',
#  '청주청원경찰서, 112신고 현장대응능력 강화 FTX 훈련',
#  "호국보훈의 달 물빛광장 '태극기' 설치",
#  "심사평가원 공식 학술지 'HIRA Research' 창간호 발간",
#  '임영웅 팬카페, 대덕구에 장학금 616만원·선풍기 30대 기탁',
#  "금산군, 60개 마을 찾아가는 농기계 수리지원 '박차'",
#  '괴산군, 새마을운동 제창 51주년 새마을의 날 기념식 열어',
#  '[동정] 이차영 괴산군수',
#  "괴산군노인복지관, '찾아가는 실버 건강대학' 운영",
#  '천안시 성정1동 한시생계지원 대상 발굴 및 안내 봉사 홍보 적극 나서',
#  '공주 영재교육 역량 강화를 꾀하다',
#  '공주소방서, 에어매트 전개훈련',
#  "공주시, '엄마와 아기 행복프로그램' 등 출산 친화 프로그램 운영",
#  '영동군, 상반기 상하수도 체납요금 징수 나서',
#  '진천삼수초, 방과 후 창의놀이교실 호응',
#  '영동군, 도내 최초 일반세대 가스타이머콕 보급사업 추진',
#  '대청호 조류대책위원회 개최…기관별 역할 논의',
#  '휴마시스(주), 충북교육청에 자가 검사 진단키트 2천개 전달',
#  '최고기온 30도 이상 더위',
#  '우즈베키스탄 보건부 장관, 충북 오송 방문',
#  '충북도, 2021년 하계 학생아르바이트 모집',
#  '허태정 시장, 6월민주항쟁 사진 전시회 개막식 참석',
#  '대전시, 현충일 특별교통대책 발표',
#  '한국소비자원, 일부 그림물감에서 유해물질 검출',
#  "대전 중구, 올 연말까지 '부모 모니터링단' 운영",
#  "강동대, 2년연속 선도전문대학 연차평가 '매우 우수' 선정",
#  '대전 동구, 오는 8월까지 어린이집 급식·위생 점검',
#  '정신질환자 감염병 격리병실 개소',
#  "일손 구하기 어려운 과수원에 출동한 '충남119'",
#  '[동정]양승조 충남도지사',
#  "서산민항 유치, 국회서 '군불'",
#  "예산 보성초병설유치원,'찾아오는 목공 예술체험의 날'실시",
#  "'5월 이달의 우수 직원'에 나종철 주무관 선정",
#  '황선봉 예산군수, 삽교역 신설 집회 120일 맞아 세종 정부청사 여섯 번째 방문!',
#  "'1회용품 사용 근절' 분야별 현황 점검",
#  '철도공단, 신호기술협의회 개최…상생발전 도모',
#  '【동정】맹정호 서산시장',
#  '홍성군, 26회 바다의 날 기념 수산자원 회복위해 종자 방류',
#  '원당중학교 충남 소년체육대회 유도부 금 2, 은 1, 동 2 수상!',
#  '농어촌공사, 여름철 집중호우 대비 농업기반시설 전수점검',
#  "SK에코플랜트, 청주 폐기물처리업체 클렌코 인수 추진 '관심'",
#  "청주시의회, 농촌일손돕기 '구슬땀'",
#  '천안, 수도권 전철 환승 추진',
#  '음성 소이면 갑산 체리마을, 체리수확 가족체험 실시',
#  '천안, 가축농가 분뇨배출 관련 지도점검',
#  '충남도의회, 외국인노동자 안전망 만든다',
#  "보은군, '속리산 모노레일' 6월말 개장",
#  '진천 덕산건강생활지원센터 본격 운영',
#  '청주시, 하계 학생근로활동 참여자 모집',
#  '충북경찰, 법주사 승려 도박사건 검찰 송치',
#  "서산시, 국회 道 전문가와 '서산 민항'건설 청신호",
#  "서산시의회 의원, 나라사랑공원에서 '봉사활동'전개",
#  '얀센 백신 예약 80만명 하룻만에 완료',
#  '충북교육연대 "학급당 학생수 20명 상한 법제화해야"',
#  '충북소방, 코로나19 방역·공직기강 암행 감찰',
#  '중부내륙철도 이천~충주 구간 12월 개통…서울 강남까지 1시간 30분',
#  '이노비즈기업들도 청주 도심통과 한 목소리',
#  "대전현충원, 6월의 현충인물 '김병호 육군소령' 선정",
#  "'청주도심 통과 충청권 광역철도 염원' 촛불문화제로 확산",
#  "충북도, '코로나 영농지원 바우처' 8월 13일까지 연장",
#  '충북도, 도내 야영장 대상 합동점검',
#  "최응기 옥천부군수 '발품 행정' 눈길",
#  "단양 황병모씨, 군 사회보장協에 성금 '기탁'",
#  '충북 봄철 산불 건수 줄었지만 피해면적 크게 늘어',
#  "산내농협, 심규태·김서운 부부 '이달의 새농민상' 수상",
#  "대전시의회 권중순 의장, '대전신세계 채용박람회 '참석",
#  '장종태 서구청장, 공약 평가 대전 유일 6년 연속 최우수 금자탑',
#  '천안, 지난 4월 냉해로 배재배 면적 절반 가량 꽃눈 고사 피해',
#  '천안, 체납차량 번호판 433개 영치',
#  "천안동남서 노인분회장 대상 '찾아가는 교통안전교육' 개최",
#  '한국여성경제인협회 세종충남지회 나눔분과 농촌일손돕기 봉사활동',
#  '[동정] 6월 2일 천안시 읍면동장',
#  "이승원 한국예총 예산지회장 '34회 대한민국 예술문화대상' 수상",
#  '예산소방서, 119신고는 이렇게 하세요!',
#  '보은소방서, 산악 국가지점번호 및 간이 구조구급함 정비 실시',
#  "2년 연속 공모 통과…해상풍력 '날개'",
#  '충남교육청, 2021년 적극행정 실행계획 수립',
#  '【동정】가세로 태안군수',
#  '김덕영 음성군 대소청소년문화의집 관장, 국무총리상, 이휘현 음성청소년문화의집 청소년지도사, 여가부장관상 수상',
#  '[결혼]윤병일 씨(음성군 균형발전국장) 자혼',
#  '[동정]조병옥 음성군수',
#  "제천화폐, 판매 3시간 만에 50억 '완판'",
#  '[동정]김돈곤 청양군수',
#  '공주시장, 어르신놀이터 등 주요 사업장 현장 방문',
#  "청양군, 아름다운 노년과 함께 '추억 속으로 사진 촬영' 행사",
#  '전략적 부패관리로 학교급식 운영 청렴도 높인다',
#  '부여군, 미래관광 전략포럼 개최',
#  '서천군, 느린우체통 엽서 1천개 누적 기념 이벤트 진행',
#  '[동정]노박래 서천군수',
#  '당진署, 여성안심귀갓길 합동 범죄예방진단 실시',
#  '임용환 충북경찰청장 영동署 방문',
#  '논산시, 내부정보 이용 투기 정황 드러나',
#  '당진시, "살아보고 결정해요!"',
#  "괴산군, 이달의 친절공무원에 '김지연' 주무관 선정",
#  '글로벌사이버대ㆍ월드케이팝센터ㆍ서울미래음대안학교 MOU 체결',
#  '기후변화로 수온 상승… 수산물 안전 주의보',
#  '[동정]황선봉예산군수',
#  '바이오융합산업 전문가 의견 수렴·논의',
#  '보령시,금연하는 건강한 생활 함께 실천해요',
#  '진천 노인복지관, 선배 자원봉사단 발대',
#  '보령시, 5월 중 열심히 일한 공무원 선정',
#  '[속보] 1일 0시 기준, 국내 코로나 신규 확진자 459명 발생',
#  '[알립니다] 신문·방송 기자 체험 신청하세요',
#  '“아버지, 수의 못입힐 만큼 처참... 엄벌을” 만취 벤츠 피해 유족 靑청원',
#  '‘성추행’ 피해 신고 女부사관 극단 선택... 국방부 “막중한 책임 통감”',
#  '성추행 피해 신고한 女중사, 혼인신고날 극단 선택',
#  '부품 밀수해 총기 만들어 판매… 현역 군인 포함한 일당 검거',
#  '전자발찌 전원 꺼진 틈타 잠적… 발찌 끊고 도주한 50대 검거',
#  '한동훈 “조국, 선동 없인 못 버텨… 수사 막는게 최악 권력비리”',
#  '얀센 백신 예약 시작… 접속자 몰려 한때 대기 6만여명',
#  '손정민 父 “수정해달라”... SBS ‘그알’이 정정한 자막 내용은',
#  '공중방역 수의사 폭행한 강화군청 공무원 감봉 2개월...후임 수의사와 근무 중',
#  '김종민 변호사 “조국 자서전, 재판 앞둔 여론몰이용”',
#  '6개월째 도피중인 피고인... 소재 파악 못하는 검찰',
#  '접종 완료자는 요양병원서 얼굴 맞대고 면회',
#  '노후 주택가에 예쁜 5층… 거주·임대 ‘두 토끼’ 잡아',
#  '김오수 “검찰, 직접수사 절제해야... 시대변화 못 따라가 개혁대상 됐다”',
#  "일몰제 앞둔 제주 도심공원 민간특례사업 ‘속도 낸다'",
#  '文대통령, 김오수에 “검찰이 바로서면 민주주의 발전”',
#  '여경의 男사우나 습격 사건, 뒤늦게 밝혀진 반전 사연',
#  '해경님 나이스샷!',
#  '대구 의료계, 화이자 3000만 명분 공급 추진',
#  '어린 자녀 때리고 성추행한 ‘나쁜아빠’ 징역 5년',
#  '“2050년 바닷속에 물고기보다 플라스틱이 더 많을 것”',
#  '김형연 前비서관, 최강욱 변호인단에 합류',
#  '‘새마을운동’ 중앙아시아로 진출한다...영남대·타지키스탄 국제협약 체결',
#  '윤석열과 어깨동무 식당주인 “이게 성희롱? 정치인들 한심”',
#  'SBS “정민이 친구 변호사가 SBS부장과 친분? 가짜뉴스 법적 대응”',
#  '‘중국 귀화’ 전 쇼트트랙 대표 임효준, 후배 추행 사건 무죄 확정',
#  '김상호, 해임 효력정지 가처분 2심서 승소… 대구대 총장직 복귀',
#  '10차선 무단횡단하던 여성, 택시 2대에 치어 숨져',
#  '대북전단 살포 막겠다고 특별팀까지 만든 경찰',
#  '6·10 만세운동 네 명의 주역 ‘6월의 독립운동가’',
#  '코로나로 중단됐던 국민참여재판 9개월 만에 열려',
#  '안개로 소방헬기 못뜨자, 4시간 암벽타고 북한산 추락男 구했다',
#  '대통령기 야구대회서 타자 친 공 맞은 투수 의식불명',
#  "[윤대현의 마음 속 세상 풍경] [57] ‘악수 뒤 손 닦기'와 ‘행동적 면역 시스템’",
#  '[유용원의 밀리터리 시크릿] ‘교도소보다 못하다’는 군 부실급식 5대 해법(1)',
#  '4조 코인사기 130명 집단소송',
#  '[부음] 공영수 별세 외',
#  '대검 ‘이광철 기소 뭉개기’에 오인서 수원고검장 항의 사표',
#  '[윤희영의 News English] 남성 비하 손가락 논란이 불러온 정치적 파장',
#  '강원도, 전국 최초 ‘코로나 의료·방역’ 수당 도입… 하루 1만원 지급',
#  '가상화폐로 마약 판매 521명 붙잡아… 대마초 등 108억원어치 압수',
#  '대학원생 24% “성희롱·성폭력 경험”… 피해자 65% “교수가 가해”',
#  '5·18민주화운동진상규명조사위, 군·경 피해 조사 개시',
#  '강제추행 혐의 오거돈, 첫 재판 2시간 45분만에 끝.. 국민참여재판은 거부[종합]',
#  "172명 탄 여객선 앞에 포탄 4발 ‘쾅, 쾅, 쾅, 쾅'... 아찔한 함정 시험사격",
#  '“수퍼마켓인 줄” 수심 1만m 해연, 첫 탐사자가 발견한 건…',
#  '아시아인 위협한 美노숙자, 경찰까지 공격... 행인들이 제압했다',
#  '스님, 그 방에서 뭐 하셨나이까… 검찰 송치된 승려들, 왜',
#  '입 꾹 다문 당진 자매 살해범... 피해자 부모 “사형 처해달라”',
#  '얀센, 80만명분 1차예약 마감... 오후 4시반부터 10만명분 2차예약',
#  '조국의 자문자답…“왜 지금 출간? 그럼 대선 경선때 책 내나”',
#  '조주빈 부친 “범죄단체조직은 지은 죄 아닌 ‘만든 죄’” 혐의 부인',
#  '강남 한복판서 전처와 재산 싸움… 흉기로 살해한 80대',
#  '‘부동산 투기 의혹’ 전북도청 간부 혐의 부인',
#  '사표 낸 검찰 간부들 작심 비판... “검찰개혁 한다며 독립성 해쳐”',
#  '한라산 백록담 남서쪽 암벽 200㎡ 붕괴',
#  '신분당선 연장되면 강남 직결 1700가구',
#  '한방에 끝나는 얀센 백신, 오늘부터 예약',
#  '[기고] 우리사회, 아이들에게 한없이 관대한 우주이길',
#  '섬·어촌지역 주민 교통권 더 강화',
#  '인사 - 2021060117',
#  '[인터뷰│정원오 서울 성동구청장] "전 종목 전용시설 확보할 것"',
#  "경기도, '경기바다 여행주간' 운영",
#  '유진기업 자원개발 우수논문 수상',
#  '장애인부모연대, 의료기사법 지지선언',
#  '경북도 지역사랑상품권 1조원 확대 발행',
#  '주방용 오물분쇄기 사용 금지 촉구',
#  '주민자치 법제화 운동 첫발 내딛었다',
#  '배달앱에 허위 리뷰 작성, 실형 확정',
#  '"전액 시비로 이건희 미술관 짓겠다"',
#  '식기세척기서 화재, 제조사 책임',
#  '경북도·대학 "지방소멸 공동대응"',
#  '공공폐자원관리시설 이익, 주민과 나눈다',
#  "환경부·지자체, 의료폐기물 소각장 '갈등'",
#  '여성변호사들, 성희롱·성범죄에 취약',
#  '성남 재개발서 LH 직원 투기 의혹',
#  '백신접종, 건강보험 빅데이터 한몫',
#  "[우리동네 힐링명소 | 서울 성동구 '중랑천 응봉체육공원'] 14.2㎞ 물길따라 운동·여가 즐긴다",
#  '[장시간 노동 해소 | 주52시간제] 7월부터 5인이상 사업장도 주 52시간제 도입',
#  '1953년 근기법, 법정근로시간 첫 규정',
#  '가리봉시장 부지에 청년주택 들어선다',
#  "수원시, '코로나19 방역택시' 20대 운행",
#  '공영쇼핑, 복날 보양식 특집전',
#  "'노동시간 단축 현장지원단' 활약 돋보여",
#  '인천 소래포구 물류센터 설립허가 놓고 논란',
#  "해양 플라스틱 자원순환 위해 '맞손'",
#  "부천문예회관 명칭 '부천아트센터'로 확정",
#  '군포시, 공직자 토론촉진자 20명 배출',
#  '11번째 의병의날 기념식 열려',
#  '지적재조사 민간참여 확대',
#  '시흥 매화산업단지에 제조업 특화 지식산업센터 공급',
#  '안산시, KT 데이터센터·R&D시설 유치',
#  '화성시, ICT생활문화센터·공동기반시설 개관',
#  '횡성 엔초이스 이노비즈 지정',
#  '[여론마당]전동킥보드 안전하게 타는 법',
#  "캠프페이지 '기준치 47배' 토양오염",
#  '“교도소 출소후 취업 안돼서” 강도혐의 20대 붙잡아',
#  '[횡성]횡성군 납세고지서 어르신 맞춤형 제작',
#  '[포토뉴스]알프스대영CC 후원금 전달',
#  '[홍천]동학혁명기념 백일장 수상자 선정',
#  '한라대 재학생들 춘계학술대회 우수논문상',
#  '[화천]15·27사단장 이·취임식',
#  '[포토뉴스]㈜삼부종합건설 애향장학금 기탁',
#  "양구 외가인 임영웅 '더트롯쇼' 3개월 연속1위",
#  '환경교육·홍보활동 / 춘천YMCA',
#  '[삼척]“삼척~강릉 고속전철 조기 착수해야”',
#  '[원주]“민관협력 통해 소외계층 지원 앞장”',
#  '[강릉]강릉 해수욕장 발열 환자 드론으로 찾아낸다',
#  '[포토뉴스]케이블카 사고 대응 훈련',
#  "강원도 '코로나 대응요원'에 전국 최초로 자체 수당 지급",
#  '신입생 교복 품질검사 실시',
#  '[원주]사고 많은 급커브 도로 대책 급하다',
#  '[횡성]횡성군 2개과 신설…보건소 조직 확대',
#  '[양양]양양지역 불법주정차 단속 강화',
#  '[포토뉴스]속초해양경찰서 해상·수중 정화활동',
#  '[포토뉴스]강릉단오제 축제부스 대신 단오등 설치',
#  '[동해]코로나 백신 1차 접종 동해시민 13.7% 완료',
#  '[철원]“전문가·주민 참여 철원 발전정책 도출”',
#  '[포토뉴스]보이스피싱 예방 공로 이태균씨에 감사장 수여',
#  '[포토뉴스]제대군인지원센터 조경기능사 과정 입교식',
#  '[양구]미시령터널 통행료 감면 전용카드 발급신청 접수',
#  '[화천]화천 백신접종 주민 거리두기 완화',
#  '[태백]“6·25참전 태백중 전몰학도병 구국 정신 받들자”',
#  '[포토뉴스]홍천군재향군인회 6·25참전유공자 대상 봉사',
#  '[포토뉴스]홍천군자원봉사센터 의료진 감사 물품 전달',
#  '백신접종센터 안내봉사 나선 어르신들',
#  '[철원]야간방역소독 실시',
#  "양양군 '취소 통보' vs 도체육회 '강행 의지'…미궁에 빠진 도민체전",
#  '[포토뉴스]유나경씨 여성가족부 장관 표창 수상',
#  '[홍천]농공단지 물류비 지원',
#  '환경보전·생활실천 / 박봉화·이현주씨 부부',
#  '[춘천]“춘천 K-바이오 랩허브 구축사업 최적지”',
#  '[홍천]홍천 올바른 재활용 위해 자원관리도우미 채용',
#  '전면 등교 앞두고 급식실 방역 강화 착수',
#  '[원주]원주에 도내 최초 국립전문과학관 조성 가속',
#  '[포토뉴스]동해 예람중학교 등굣길 교통안전 캠페인',
#  '[포토뉴스]“강원세계산림엑스포 성공 개최하자”',
#  '[속초]속초 장애인용 TV 53대 보급',
#  'LH 작은도서관 근무자 모집',
#  '[발언대]“걸음마도 못하는 퇴비부숙도 검사 제도”',
#  '지인 만남 통한 지역이동 연쇄감염 잇따라',
#  '“상공인 경쟁력 강화·권익보호 힘쓸 것”',
#  '[포토뉴스]태백시 세외수입 우수사례 발표',
#  '[정선]산림병해충 예찰 방제',
#  '[평창]평창 고령운전자 면허 자진반납 지원 확대',
#  '자살시도 주민 구한 철원 집배원 오병훈씨',
#  "[양구]조인묵 양구군수 '거버넌스 지방정치대상' 우수상",
#  '[영월]영월 여성농업인에 복지바우처카드 제공',
#  '[포토뉴스]최명서 영월군수 삼옥3리 마을만들기사업 현장점검',
#  '학술연구·기술개발 / ㈜예스코이에스',
#  '환경보호운동 / 진인동 홍천 자운2리 이장',
#  '[포토뉴스]원주디지털사무기 저소득층 학생에 노트북 기탁',
#  '[이슈현장 홍천]일제 빼앗긴 옛 지명 100년 만에 되찾아',
#  '[고성]미시령 옛길 통행 재개',
#  '강원도의회 조선왕조실록·의궤 환수 힘싣는다',
#  '[포토뉴스]허필홍 홍천군수 홍천사랑카드 발급',
#  '[포토뉴스]김한근 강릉시장 박영범 농식품부 차관 면담',
#  '[확대경]주 52시간 속도조절 필요',
#  '한낮 춘천 29도 강릉 27도 일교차 10도 이상 벌어져',
#  '“삼척~제천 고속도 신속추진”',
#  '제자들에게 폭언·체벌 고교 교사 벌금 700만원 선고',
#  '강릉에 이산가족 화상 상봉장',
#  '춘천 법조타운 국비 확보전 돌입',
#  "[고성]산불 피해 고성 성천리에 '경기의 숲' 조성",
#  '[포토뉴스]횡성군여성단체협의회 구제 의류 판매 봉사',
#  '[포토뉴스]참빛영동도시가스 사회복지관에 가전제품 지원',
#  '[포토뉴스]양양읍새마을부녀회 어르신께 밑반찬 전달',
#  '“백신 맞고 함께 모이니 행복” 일상 되찾은 어르신들',
#  '동해시청 공무원 숨진채 발견',
#  '[속초]속초 특별교통수단 확대',
#  "강원환경대상에 '오대산 주민환경지킴이'",
#  '“악성댓글에 성적 수치심 느껴” 윤희주 강릉시의원 고소장 제출',
#  '[강릉]도농업인수당 추가 접수',
#  '대상 / 오대산국립공원 생태보전벨트 주민환경지킴이',
#  '"접종해도 수칙 지켜야"',
#  '"세상을 바꾸는 실천, 모두 함께해요"',
#  '제주시 문화도시추진위 위촉식',
#  '류성필 제주TP 정책기획단장',
#  "개장도 하기전에 '무법천지'된 해수욕장",
#  '렌터카-버스 충돌…5명 사상',
#  "일몰 앞둔 도시공원 민간특례 '기로'",
#  '서귀포시, 오는 4일까',
#  '코로나19',
#  "마무리 아닌 이제 '시작'",
#  '2025년까지 역량 강화',
#  '팔색조 애월읍서 구조',
#  '제민일보, 편집심의위 회의',
#  "강정…14년만에 '갈등' 굴레를 벗다",
#  '제주시 야영장업 안전점검 방역 강화',
#  '도 공모 선정…진흥 계획 추진',
#  "깨지고 갈라지고…'누더기 도로' 눈살",
#  '제주RCY 창립 66주년…"인도주의 활동 최선"',
#  '한국마사회 제주지역본부',
#  '배출가스 5등급 차량 단속 유예 연장',
#  '청소년 노동인권보장 "당연한 일"',
#  '알작지 피해 복구한다며 원형 파괴',
#  '서귀포시, 토지이동 일제 조사 정리',
#  '갑자기 날아온 흑인 주먹…뉴욕 한복판서 아시아女 기절 [영상]',
#  "김오수 취임날 떠나는 고검장들 '박범계식 검수완박' 때렸다",
#  '[서소문 포럼] 공권력이 만든 ‘방구석 코난’',
#  '[사랑방] ㈜우아한형제들 김봉진 의장 外',
#  '베이비박스에 생후 2개월 아기 두고 사라진 부부 집행유예',
#  '백신 접종 이후 60대 이상 확진율 11%p 감소…파주시 분석',
#  '이재명, 음성판정 뒤 ‘능동감시’전환…총무과 직원 2명은 확진',
#  '용의자는 英억만장자 며느리…벨리즈 경찰 의문의 총격사망',
#  '김오수 첫 시험대는 ‘월성 의혹’ 백운규·채희봉 처리',
#  '"생물 5295종 서식, 문화재 91점"…팔공산 국립공원 노린다',
#  '"박사 가면 숨어 비열했던 과거, 부끄럽다" 조주빈 친필 사과 [전문]',
#  '교도소 출소 후 취업 어렵자 가정집 침입해 강도질한 20대',
#  '"법이 혼내주길 바란다" 박사방 조주빈, 오늘 2심 선고',
#  '택배기사·보험설계사도 다음달부터 실업급여 받을 수 있다',
#  '35세 여교사 제자와 성관계…17세 남학생은 "사랑이었다"',
#  '남양주 개물림 사고에, 강형욱 "눈치보지 말고 안락사 시켜야"',
#  '"주말 비 안온다더니"…춤추는 \'세발낙지\'에 곤혹스런 기상청',
#  '분홍색 가득한 공원 어때? 마음껏 색칠해봐...양천구, 컬러링 공모전',
#  '대구한의대학교, 동의한방촌사업단 2021 명품 DG FESTA 참여',
#  '"애셋 유부녀야, 헤어져"…50대女 협박한 31세 男도우미 최후',
#  '與, 공군 부사관 성추행 은폐 사망 사건 "깊은 자괴감…가해자 엄벌"',
#  "얀센백신 새벽에만 수만명 몰렸는데…영등포구, 명단누락으로 '먹통'",
#  '‘금감원 직원 사칭’ 수억원 가로챈 50대 보이스피싱 조직원 구속',
#  '확진자 2명 나온 울산 "\'영국 변이 감염\' 사슬 끊은 것 같다"',
#  '울음 터트린 만취 벤츠女…유족 "아버지 숨진 곳서 울었다"',
#  '김흥국 \'오토바이 뺑소니\' 혐의 송치···경찰 "신호위반 과실" [영상]',
#  '서욱, ‘성추행 피해 극단적 선택’ 공군 女부사관 사건 엄정수사 지시',
#  '허위 농업계획서로 산 농지 팔아 260억 수익…영농법인 대표 영장',
#  '[단독]수신료 인상 토론참여자 30만원씩 준 KBS…80%가 "찬성"',
#  '김오수 "방파제돼 부당한 압력으로부터 정치적 중립과 독립성 지킬 것"',
#  '[단독]공수처 유일준 "이성윤 공소장 공개, 내부 징계도 무리"',
#  '출근길 중부 약한 비…낮기온 25도 이상 ‘초여름’',
#  '양부모 학대로 숨진 정인이···경찰, 아동보호기관 무혐의 처리',
#  '줄사표 검찰 고위급 "장관·총장 수사 승인, 독립성 심각 훼손"',
#  '"오빠" 아가씨의 마지막 호객…60년 수원역 홍등가 불꺼졌다',
#  '"멀쩡하던 어머니·외삼촌, 화이자 접종뒤 같은날 숨졌다"',
#  '슈퍼모델 골프단, 대한사회복지회에 화장품 후원',
#  '조국에 분노한 한동훈 "이렇게 할 말 많은 사람이 증언거부"',
#  '[속보] 첫 출근 김오수 "수사지휘 하나씩 구성원 믿으며 할 것""',
#  '서울시 "노래방 종사자 2만명 코로나 검사…안 받으면 벌금"',
#  '경찰, 이용구 폭행 사건 담당수사관·택시기사 재소환',
#  '대통령기 야구대회서 공에 가슴 맞은 중학생 투수 의식불명',
#  '금천구, 생태·놀이·아이중심…생태친화어린이집 운영',
#  '코로나19 연관 소아 다기관염증증후군 우리나라 다섯번째 사례 발생',
#  '강남 한복판 삼성화재건물서 집단감염 20여명…전직원 재택',
#  '서브원-유한킴벌리, ‘B2B 고객사 대상 ESG 적합 제품 활성화 협약’ 체결',
#  '한국안전전문가협회 공식출범...대한민국 안전 대책과 안전 예방활동 참여',
#  '경찰, 전북도청 또 압수수색…부동산 투기 자료 확보 주력',
#  "'조국의 시간'은 '법원의 시간'과 이렇게 달랐다 [팩트체크]",
#  "'강등' 요구했는데 '정직'…경기도,산하 기관 제식구 감싸기 손질",
#  '"한날한시 두 딸 목숨 잃었다, 사형 선고해달라" 부모의 오열',
#  '한국산업기술대, 산학협력 거점형 플랫폼사업 참여기업 기술교류회 개최',
#  '"성추행 여군의 비참한 죽음, 엄정 수사하라" 정치권도 성토',
#  '항공업계, "무급이면 굶어죽어…고용유지지원금 연장해야"',
#  "만취상태 운전하다 택시 꽝…'애프터스쿨' 출신 리지, 檢송치",
#  '윤석열, 권성동 만나기 나흘 전 정진석과 회동…국민의힘 입당 촉각',
#  'AZ 맞은 30대 남성, 국내 첫 희귀혈전증',
#  '이광철 기소 미루는 조남관에 반발, 오인서 수원고검장 사의',
#  '[사진] 무너진 한라산 백록담 암벽',
#  '[서명수의 노후준비 5년 설계] 자녀 결혼, 얼마 지원해야 하나?',
#  '대구 의료계 "화이자 백신 3000만명 분 확보 추진"…"정부 구매 지원"',
#  "대프리카 더위사냥 비법은 '그늘'…양산 대여소 140곳 운영",
#  '직원 강제추행 혐의 오거돈 전 부산시장 오늘 첫 재판',
#  '[오늘의 날씨] 6월 1일',
#  '[한 컷] 해수욕장 개봉박두',
#  '[사랑방] 인천 동구, AI 돌봄 시스템 구축 MOU',
#  '"우리 마을 떠나라" 술병 투척…대만 확진 모녀, 밤새 떨었다 [영상]',
#  '익산 바이오, 순창 고추장…지역과 협업 ‘특성화 캠퍼스’가 혁신 경쟁력',
#  '가수 박군 울산 중국집 뜨자, 군복의 중년 4명 차 에워쌌다 [영상]',
#  '오늘도 코로나 확진자 500명 아래 예상…재확산 가능성 여전',
#  '오거돈 첫 법정 출두…모자 벗으며 "피해자·시민께 죄송"',
#  '\'절반 접종\' 美 신규확진 1만명 아래로···파우치 "갈 길 멀다"',
#  '아동‧청소년이 즐거운 도시...동작구, 아동친화도시 특화사업 추진',
#  '"맨밥에 깍두기" 발칵 뒤집힌 軍급식…범정부TF 띄운다',
#  '“왜 새해부터 처가에 있어야하나” 아내·아들 폭행한 30대 남성 ‘징역 2년’',
#  "'한강대학생 사건' 친구·미화원까지 '법최면'…왜",
#  '휴온스, 포용적 사회문화 조성 위한 성평등기금 전달',
#  "부품 들여와 진짜 권총 만들었다, 300만원에 판 '고스트 건' [영상]",
#  '[경제브리핑]LG상사, LX인터내셔널로 임시주총서 사명 변경',
#  '"김태현 반성문 어이없다, 인간쓰레기조차 아냐" 유족 분노',
#  "370만 예비군·민방위 줄 세운 '얀센 백신' 마감 임박…효과는?",
#  '여가부 “부사관 성추행 사건 안타깝다···조직문화 점검 필요"',
#  '김오수에 임명장 건넨 文 "검찰 바로 서면 민주주의 발전"',
#  '“손 안의 역사 여행, 든든한 대한민국” 희망친구 기아대책, 기아㈜와 경기도 초등생 역사 교보재 지원',
#  '조국 "왜 책 냈냐 꼬투리…불리한 여론 계속 감수하란 거냐"',
#  '[영상]오리 뛰다…8차선서 발견된 오리, 경찰이 에스코트',
#  '한전공대 오늘 착공식',
#  '제11회 의병의 날 기념식',
#  '‘김광석이 김정호를 만났을 때’',
#  '초광역 에너지경제공동체 ‘호남 RE300’ 본격화',
#  '5·18 정신적 피해 일괄 배상 방안 모색을',
#  '아버지, 1년만에 뵙습니다',
#  '이재명 지지 모임 ‘민주평화광장’ 출범',
#  '한전에너지공대 ‘켄텍’ 착공 … 내년 3월 개교',
#  '1년 여만에 만지는 아버지의 손',
#  '유은학원 설립 100주년…“4차 산업시대 인재육성 앞장”',
#  '광주·전남 진보정당들도 내년 지방선거 채비',
#  '“일상 되찾자” … 광주, 코로나 백신 접종 ‘열풍’',
#  '광주FC 사무처장에 김성규',
#  '포스트 코로나 대비 공공의료기관 확충해야 - 신광식 고려인마을 법률자문단 변호사',
#  '순창읍 청소년수련관 부지에 실외 롤러스케이트장 개장',
#  '광주 5명·전남 엿새째 한자릿 수…코로나 확산세 주춤',
#  '전남인재개발원, 강진서 새출발',
#  '광주 대표 상권 충장로 옛 영화 사라지나',
#  '광주·전남 특성화고, 스마트공장 전문 인력 양성',
#  '선원 살린 스티로폼',
#  '광주시의회 “투기자본 맥쿼리, 해양에너지 인수 시도 중단하라”',
#  '국민의힘 전주혜의원 광주형 일자리 법안 발의',
#  'K-water 주암댐 쓰레기 자율관리 사업 착수',
#  '광주시 규제 입증 책임제 도입…광역단체 4번째',
#  '터널 안 교각 충돌 운전자 숨져',
#  '함평군 겨울철 위기가구 지원 우수 지자체',
#  '전남어촌특화지원센터, 정부공모사업 주민 역량강화교육',
#  '영광 ‘학생승마체험’ 인기',
#  '함평군, 우울할 틈 없는 ‘내·안·愛’',
#  '“광고 왜 안줘” 이틀새 92차례 전화 협박, 인터넷언론매체 기자 집행유예 선고',
#  '목포시 청년정책 발굴 정책위원 20명에 위촉장',
#  "공약 62.5% 해결… 임병택 시흥시장, 이행 평가 2년 연속 '최우수'",
#  "경기도, 1980년대 소유권 이전 못마친 '축구장 5.5배 크기 땅' 환수",
#  '"이건희 미술관, 수원으로"… 수원 국민의힘 \'범 시민연대\' 결성 제안',
#  "만 1살 아동 8명을 24회 폭행 '시립어린이집 보육교사' 집행유예",
#  "[날씨] 수도권 최고 29도 '더위'… 3일부터 전 지역에 '비소식'",
#  "'불법 매립·성토' 몸살 앓는 김포시, 통진읍도 당했다",
#  '[포토] 노인시설 운영재개 경로당 반가운 인사',
#  '전국보건의료산업노조 "대리수술 의혹 병원, 인증 취소해야"',
#  "'신도시 과밀학급 해소방안'… 양주서 제한적 공동학구제 여론 확산",
#  '스마트폰 붙잡고 사는 경기도 중학생, 우려대로 확 늘었다',
#  '부천문화재단, 김정환 새 대표이사 취임… 임기 3년',
#  "곽상욱 오산시장 매니페스토 공약 이행 8연속 '최우수'",
#  "[화성 입양아동 학대사건] 양부모 처벌, 이번에도 '고의성' 입증에 달렸다",
#  '[포토] "문재인 대통령, 인천공항 비정규 노동자와 만납시다!"',
#  '[포토] 부평 찾은 더불어민주당 송영길 대표',
#  "NH농협 이천시지부 김영춘 지부장 '함께하는 농협인 상' ,",
#  "[포토] 요양병원 대면면회, '오랜만의 재회'",
#  "[제2회 경인일보 '손편지 공모전'] 건강상 수상자 이홍섭씨의 편지",
#  '포천서 통신선 매설 현장 무너져… 근로자 2명 부상',
#  "[포토] 노인시설 운영재개… 외부활동 '기지개'",
#  '경기도 산하 공공기관 내부 비위행위 봐주기식 처분 개선 나서',
#  "강화도 수산물 여기 다 있네… 인천시 '산지 거점 유통센터' 이달 개소",
#  "광주-용인 민주당 시도의원 '성명서' 4차 국철망 경강선 연장 촉구",
#  '인천지방법원 국민참여재판 9개월 만에 재개',
#  "'시립화장장 추진' 이천시장 주민소환투표, 청구에 민-민 갈등으로 번지나",
#  '[포토] 수원역 앞 성매매업소 밀집지역 자진폐쇄',
#  '가평 재가 복지시설서 코로나19 집단감염… 누적 8명',
#  '경찰, 허위농업경영계획서 제출하고 농지 쪼개 판 영농법인 구속영장 신청',
#  '[알림]경인일보 청탁방지담당관 및 고충처리인 선임',
#  '민방위·예비군 얀센 백신 접종 신청해보니… 몇분이면 끝 "쉽고 간단"',
#  '[단독] 검찰, 경기도 A축협 임원선거 금품 살포 혐의잡고 수사',
#  '임기 1년 앞둔 경기도 내 시군 단체장들 성적표 공개… 최하 등급은 어디?',
#  '"싸가지 없다" 10대 딸 목 조르고 때린 \'비정한 어머니\' 징역형',
#  '[인사] 분당서울대학교병원',
#  '경기도 소비지원금 신청 폭주… 경기도 지역화폐 충전 일시 중단',
#  '"버려지는 아이스팩 모아주세요" 구리시 아이스팩 재활용 행사',
#  "광주 '중대동 물류단지'… 이번엔 국민의힘 반기들고 나서",
#  '경기도청공무원노동조합 신임 위원장에 강순하 인재개발원 주무관',
#  "종중 재산 분배 과정서 사위만 쏙 뺀 종친회 결정 '무효' 판결",
#  '김영실 남양주시의원, 호평하수처리시설 신설 "상류지역 설치 합당"',
#  "[포토 ]노인시설 운영재개 '오랜만의 담소'",
#  '성남시청공무원노조, "반복·지연되는 수사 이제는 신속한 결과 요구한다"',
#  '이재명 경기도지사, 코로나 음성… 경기도청 직원 2명 확진',
#  '최정용 가평군의원 "공공기관 모두 탈락, 군민 상실감 넘어 울분"',
#  '안산도시공사 창립 10주년, 서영삼 사장 혁신 등 5대 경영 방향 제시',
#  "[포토] 요양병원 대면면회 허용… '여보, 잘 지냈나요'",
#  '한강유역환경청, 가시박·큰입배스 등 생태계 교란종 퇴치사업 집중 추진',
#  '[포토] 부평 찾은 송영길 "국민 속에서 듣겠습니다"',
#  "'학생 수요 예측 실패' 경기도 신도시 학교들 '과대화' 후유증",
#  '하남시, 3기 교산신도시 자족도시 성장동력 확보 나선다',
#  '분당차병원 김영상 교수팀, 중노년층의 칼슘부족과 근감소증 상관 관계 밝혀내',
#  "태어나면서부터 노년까지… '양평에 살면 모두가 행복해요' 발간",
#  '교회 베이비박스에 생후 1개월된 딸을 두고 떠난 20대 부부 유죄',
#  '발달·시각 중복장애인을 위한 진로·직업체험 특별훈련과정 운영',
#  '[포토] 문닫힌 성매매업소 바라보는 시민들',
#  '[포토] 문닫은 수원역 앞 성매매업소',
#  '[포토] 자진 폐쇄한 수원역 앞 성매매업소들',
#  "파주시 산불 발생률 56% 줄인 비결 '대응센터' 신설에 있었다",
#  "하남시, 감일동 신촌 도시계획시설 이어 공원부지마저도 축소해 '특혜 논란'",
#  "국민의힘 김선교 10차 공판 '미신고후원금' 열띤 공방",
#  "[포토] '꼭 잡은 두손'… 요양병원 대면면회 재개",
#  '[인사] 한동건설(주)',
#  "[포토] 노인시설 운영재개 '웃음꽃'",
#  '코로나 이전 일상 회복 지원… 수원, 2차추경 2821억 증액',
#  '적십자 인천여성봉사특별자문위원회 위기가정 기부금 500만원',
#  "[포토] 인천시·굿네이버스 '보훈증진과 나눔기부 확산 협약'",
#  '[포토] 경기도미래기술학교 추진 업무협약',
#  "[포토] '백신 맞고 기지개' 노인복지시설 운영 재개",
#  '당정, LH 혁신안 오늘 재논의… 이르면 내일께 최종결론 발표',
#  "[포토] 공공운수노조, 비정규직 제로화 요구 '도보 행진'",
#  "교통약자를 위한 예약체계 마련… 임오경 '이동 편의 개정안' 발의",
#  '[경인 WIDE] "공공기관 이전, 역부족"… 경기 남부와 격차 더 커져',
#  '경기도청 직원 2명 확진·이재명 경기도지사 격리',
#  "[인터뷰… 공감] 공무원 해직·명예 회복·523번 버스기사 '롤러코스터' 고광식 씨",
#  "['연수 서해그랑블 에듀파크' 분양] 강남까지 30분… '도심 속 숲세권' 명품단지",
#  'ASF 방역에도 비상 걸렸는데, 수의사 강화군 배치 빼 달라니',
#  "[제2회 경인일보 '손편지 공모전'] 행복상 수상자 정낙민씨의 편지",
#  '한신대 제8대 총장에 신학부 강성영 교수 선임',
#  '크로스 체킹… 타지역 유출 경기도 세금 34억 찾았다',
#  '미스터 달팽이 2021년 6월 2일자(이공명)',
#  '[오늘의 창] 광주~이천~여주, GTX노선 왜 필요한가',
#  '[수요광장] 시청료 인상 추진으로 불거진 공영방송 책무의 역설',
#  '[코로나19 시대 인천시민 건강 리포트·(4)] 피부과-염색약 등 알레르기 반응 주의',
#  '인천언론인클럽 회장에 박희제 동아일보 본부장',
#  '수원축산농협 "협동조합다운 조합 모델 만들것"',
#  "1인당 50만~150만원 제공… '돈선거' 얼룩진 수원축협",
#  "강화 수산물 '거점유통센터', 이달중 외포리서 운영 시작",
#  '경기도, 아동일시보호소 1곳·학대피해아동쉼터 8곳 추가',
#  "인천뮤지엄파크 지난주 비공개 중투심… 다가온 '문화계 드림'",
#  "국가철도망 확정 초읽기에 김포 국회의원들 'GTX-D 강남연결 반영 결의' 오늘 삭발식",
#  '인천 계양구 귤현동 철도부지 일대, 불법경작·농업폐기물 배출 심각',
#  '미스트롯 홍자 방음벽조류충돌방지 자원봉사',
#  '장현국 경기도의회 의장, 6·25 전사자 고 윤덕용·강성기 일병 희생 추모',
#  "고양시, 행주 관광 명소화를 위한 '행주관광발전협의체' 가동",
#  "'당원이 되어주세요'… 국민의힘 평택갑 당협, 현장에서 당원 모집",
#  '"아이키우기 좋은 도시로"…서철모 화성시장, 스마트 어린이보호구역 안전시스템 구축 현장 점검',
#  "'경기도북부자치경찰위원회' 설치 관련 법령개정안 국무회의 통과",
#  'GH, 안양 관양고 주변 도시개발사업 속도…부지조성 시작',
#  '김오수號 본격 출범, 검찰 조직개편 등 현안 처리 관심',
#  '대한적십자사 경기도지사, 강남대 대학적십자회 창단',
#  '장현국 경기도의회 의장 "본격적으로 시작될 자치분권 시대 준비해야"',
#  '"약속했던 사업들 완수하겠다"…엄태준 이천시장 공약이행평가 \'A등급\'',
#  '아이 키우기 좋은 환경 조성 위해…평택시, 다자녀가정 양육지원금 지급',
#  "온실가스 감축사업 발굴 나선 이천시, '2050 탄소중립' 공동 선언 동참",
#  '"나만의 색을 찾다"… 여주시 청년활동지원센터, 이미지메이킹 프로그램 마무리',
#  '양성평등 실현 나선 의정부시, 성별영향평가 사업담당자 맞춤형 컨설팅 실시',
#  '"적극적 마인드가 동구를 바꾼다"… 인천 동구, 적극행정 우수사례 발표회 개최',
#  '금연 실천 분위기 확산 나선 과천시 보건소, 과천 위버필드 제2호 금연아파트 지정',
#  '경기관광공사, 이해충돌 방지 청렴 서약식 개최… 반부패 청렴문화 확산 앞장',
#  '"북한이탈주민 안정 정착 위해"…안성시, 경기도의료원 안성병원과 의료지원 업무협약 체결',
#  '"일상 속 걷기 활성화"… 여주시, 경강선 세종대왕릉역에 건강 계단 조성',
#  '"\'G&B 프로젝트\' 성공 추진 위해"…의정부시, 부시장·4급 이상 공직자 기념식수',
#  '안산시, 신년 정책미팅 통해 수렴한 시민 정책제안 99% 추진',
#  '"마감 임박!"… 고양시 \'한시 생계지원금\' 오는 4일 현장신청 마감',
#  '(노트북)임오경, 간선철도에 교통약자 별도 예약체계 마련',
#  '신용보증기금, 창립45주년 기념식 개최… 반부패·청렴 캠페인 나서',
#  '농지 되팔아 255억 수익 챙긴 농업법인 대표에 구속영장 신청',
#  '김현정 민주당 평택을지역위원장, 평택호 수질관리 지역협의체 결성 이끌어',
#  '"창의적인 의견 수렴"… 평택도시공사 \'고객 아이디어 공모전\' 2차 접수',
#  '벼랑 끝 소상공인들… 소상공인 10명 중 9명 "최저임금 동결해야"',
#  '경기도자원봉사센터-트로트 가수 홍자 "야생조류 유리창 충돌 이제 그만"',
#  '경기도, 30년 넘게 등기이전 안된 축구장 5.5개 규모 지방도 소유권 확보',
#  '경기도장애인체육회 노조, 가맹단체 실무자 협의회 업무협약 체결',
#  '대중교통 5개년 계획 수립 첫발 내딛은 파주시, 지방대중교통계획 용역 착수',
#  '[오늘날씨] 전국 구름 많고 경기·강원 새벽에 빗방울… 수원 17~26도·인천 17~23도',
#  '"청년의 내일을 위해"…이천시, \'청년지원정책위원회\' 출범',
#  '"미래세대를 위한 바다로"… 안산시, 제26회 바다의 날 맞이 미꾸라지 방류',
#  '"도서관 책으로 꾸미는 우리 집"… 산본도서관, \'우리 집은 작은도서관\' 운영',
#  "인천 동구 송림3·5동 새마을지도자협의회, 취약계층 위한 '사랑의 쌀 나누기'",
#  '"맞춤형 징수로 조세 정의 실현"… 광명시, 체납관리단 출범',
#  "실종 어르신 무사히 '가족 품으로'… 이천통합관제센터 한 요원 감사장 수상",
#  '풋살장·족구장 인조잔디 조성…안양시, 박달동 친목마을 생활체육시설 개장',
#  '인천시, 굿네이버스와 살맛나는 세상 만들기 나선다',
#  "수원축산농협 'Suwon Lico Way 2030, 협동조합다운 협동조합 모델' 비전 세워",
#  'iH공사, 2021년 노후 공공임대주택 그린리모델링사업 보조사업자 공모',
#  "경기도, 산하기관 '셀프 솜방망이 처벌' 막는다… 징계규정 개선 착수",
#  '부실 타워크레인 현장 퇴출… 임대사업자 "소모품만 바꾸면 된다" 반발',
#  '사위 쏙 뺀 종중재산 분배… 법원 "아들·딸 몫과 동등하게 줘야"',
#  "병무청, 14일까지 '2021년 산업기능요원 채용박람회' 개최",
#  '[와이드인터뷰] 윤건모 수원시 행정동우회 회장 "동우회 활동 범위 넓히고 영향력 키울 것"',
#  '안전검검의 날 캠페인 실시한 오산시, "여름철 폭염 충분한 물 섭취와 휴식으로 예방합시다"',
#  '2일 수도권 대체로 맑아',
#  '[오늘의 운세] 2021년 6월 1일 화요일(음력 4월 21일/일진:경진(庚辰)/띠별·생년월일 운세)',
#  '"군민들과의 소통을 위해"… 양평군, 온라인 군민토론방 시범 운영',
#  '국민의힘 수원 인사들 "\'이건희 컬렉션\' 유치 범시민연대 결성" 촉구',
#  "'친환경쌀 재배단지 육성'… 안산 군자농협, 우렁이 방사행사 가져",
#  '양평군, 양동면에 삼산보건진료소 개소… 취약한 의료 환경 개선 기대',
#  "11월까지 총 21회 참여…화성시, '2021년 빌딩 숲 텃밭 정원사' 모집",
#  '미래이천시민연대 "시립화장장 반드시 추진" 합창',
#  "고금란 과천시의회 부의장, 道 시·군의회 의장협의회 '제10회 의정활동 우수의원' 선정",
#  '인천농협, 청년조합원 육성·도농상생 협력을 위해 힘 모은다',
#  '인천시, 버스탑재형 이동단속 18대 추가 설치',
#  '친환경에너지 보급 확대 나선 안성시, 단독·공동주택 미니태양광 설치비 80% 지원',
#  '인천 계양·서구, 매니페스토 기초단체 평가서 최고등급 받아',
#  "수원시 '시장 공약이행·정보공개' 최고점 받았다",
#  '사의 표명한 검찰 고위간부들, 정부 검찰개혁 방향에 우려 표명',
#  '인천시 예산바로쓰기 시민감시단, 예산낭비 감시 매의 눈 가동',
#  "김포 국회의원들, 2일 'GTX-D 원안사수'·'서울5호선 김포연장' 촉구 삭발투혼",
#  '만 1세 아동 폭행한 어린이집 교사, 징역형의 집행유예 선고받아',
#  '[이심전심] 의료기관의 회생신청-기존 강제집행의 취소',
#  '대한적십자사 경기혈액원, ㈜에스제이엠과 생명나눔 협약',
#  "이재명, 4번째 코로나 검사 결과 '음성'…경기도청 직원 2명 확진",
#  "10~13일 킨텍스서 국내 최대 규모 '2021 고양가구박람회' 개최",
#  '"평택항 위치한 국제도시, 유치 최적지"…평택시, \'이건희 미술관\' 유치 본격 추진',
#  '경기 116명 신규 확진…어학원·어린이집서 감염 잇따라',
#  '포천시 일동면 도로서 통신선 지중화 작업 중 지반 무너져…작업자 부상',
#  '"돕고 돕는 사회 되기를"… 더 나눔, 평택시 송탄출장소에 라면 60박스 기부',
#  '자치분권 실현 위해… 평택시의회, 지방의회법 제정 촉구',
#  "양평군·군포시, 경기도 특별조정교부금 160억원 수상…정책공모 '대상'",
#  '경기도체육회 경기단체 지원금 도가 직접 관리, 까다로워진 절차에 불만',
#  '안양 박달동 한 주유소 유조차서 경유 유출... 市 진공흡입 등 조치',
#  "수원시 '서수원 문화시설 건립' 등 민선 7기 공약사업 담은 제2차 추경예산안 제출",
#  "사회적약자 배려 위해… 평택시·희망누리사회적협동조합 '엄마사랑 식판케어' 개업",
#  '매니페스토 공약이행 \'8회 연속 최우수등급\' 곽상욱 오산시장, "공약 차질 없이 이행할 것"',
#  '촘촘한 안전망 구축 노력한 의왕시, 겨울철 복지위기가구 발굴·지원 우수지자체 기관 표창',
#  '더불어민주당 경기도당, 농림축산 현안 등 농정간담회 개최',
#  '"살기 좋은 시 만들어요"… 광명시, 시민참여커뮤니티 2기 60명 모집',
#  "취약계층에 식품·생필품 무료 제공…구리시 수택1동, '희망(Dream)·행복 드림 냉장고 사업' 시작",
#  "'고의체납자 정리 위해'… 용인시, 체납관리단 108명 활동 시작",
#  '대통령기 야구대회서 공맞은 투수, 현재 의식불명',
#  "예비군 등 '얀센백신' 예약 시작…1회 접종으로 면역 이점",
#  '손씨 친구 폰 2주간 사물함에 넣어둔 이유는?···"병가였다"',
#  '권영진 대구시장, ‘이건희 헤리티지 센터’ 건립 건의',
#  '교섭 1년 끌다 파업권 잃은 르노삼성 노조…불법 파업 가나 [김일규의 네 바퀴]',
#  '"차 좀 빼주세요" 한마디에 경비원 5년 괴롭힌 입주민 [영상]',
#  '[속보] 김오수 "수사관행·조직문화 혁신…檢, 시대변화 따라가지 못해"',
#  '조국 "윤석열, 文도 \'잠재적 피의자\'로 인식…\'한동훈 중앙지검장\' 요구"',
#  "'극단선택 압박하자'는 댓글까지…손씨 친구 법적대응 나선다",
#  '[포토]"카트 비정규직도 정규직으로"...인천공항 노동자 청와대 행진',
#  '[속보] 백신 1차접종 38만5535명↑…인구대비 11.3%인 579만1503명 누적 접종',
#  '"정액 검사할 때 도와주시나요?"…비뇨기과 간호조무사 \'토로\'',
#  '게임업계, 잇따라 백신 접종 휴가 도입…최대 4일까지',
#  "'파업 위기' 놓였던 삼성디스플레이, 임금협상 재개한다",
#  'DB금투, 공기업 ESG 채권 발행 시장서 ‘잘 나가네’',
#  "'주 초반' 확진자 감소 영향 끝났다…내일 600명대 후반 예상",
#  "알아두면 쓸모 있는 법률 상식…'권고사직 제안 받았다고요?'",
#  "유부녀 이별 통보에 분노…남편·자녀 앞에서 '성관계' 폭로",
#  '10대 친딸 폭행 및 협박한 40대 비정한 母 법정구속',
#  "평택시, TF팀 1차 회의열어 '이건희 미술관' 유치 본격화",
#  '김기현 "민주당의 야당 \'패싱\' 인사 \'기네스 신기록급\'"',
#  "얀센백신 사전예약 첫날…대기자 몰려 '접속 지연'",
#  '"자연실업률 3.9%…금융위기 이후 올랐다"',
#  "경기광주시, 매니페스토실천본부 전국 226개 기초단체장 공약이행평가에서 'A등급 받아'",
#  '고양도시관리공사, 고양운동장 주경기장 조명 LED 교체',
#  '[속보] 정부 "대구시에 화이자 백신 공급 제안한 건 외국 무역회사"',
#  "'조국 수사 총괄' 배성범 법무연수원장 사표",
#  '김오수 신임 검찰총장 "방파제처럼 중립성·독립성 지킬 것"',
#  '김오수 "정치적 중립 지킬 것"…조직문화 혁신 강조 [종합]',
#  "'후배 추행 혐의' 쇼트트랙 전 국가대표 임효준, 무죄 확정",
#  "'노원 세 모녀 살해' 김태현, 1일(오늘) 첫 재판",
#  "오늘부터 양도세 인상 '최고 75%'…김오수 검찰총장 취임 [모닝브리핑]",
#  "경기도, 산하 공공기관 솜방망이 처벌 차단..'인사.징계 규정 등 '뜯어 고친다'",
#  '롯데백화점 부산본점 프리미엄 IT편집숍, UP+ 매장 개장',
#  '코로나 신규 확진자 459명…여전히 2.5단계 범위에 해당 [종합]',
#  '메드팩토, 데스모이드종양 국내 임상 2상 신청',
#  '"A씨 변호사가 SBS 부장에 연락해…" SBS, 가짜뉴스 강력대응',
#  '동서대, 간호대학 실습교육 지원사업 수행기관 선정',
#  '[속보] 경찰 "손씨 친구 휴대전화에서 특이점 발견 못해"',
#  "'개훌륭' 강형욱, 남양주 들개 개물림 사망 사건 관련 인터뷰 공개",
#  '文 "검찰이 스스로 개혁 주체라는 자긍심 가져야"',
#  '얀센백신 예약 첫날 오후 3시30분께 선착순 마감 [종합]',
#  '사실상 혐의 벗은 \'손씨 친구\'의 반격 "유튜버·누리꾼 고소" [종합]',
#  ...]

# %%
# 클러스터별 주제어 추출확인
from sklearn.feature_extraction.text import CountVectorizer

def c_tf_idf(documents, m, ngram_range=(1, 1)):
    count = CountVectorizer(ngram_range=ngram_range, stop_words="english").fit(documents)
    t = count.transform(documents).toarray()
    w = t.sum(axis=1)
    tf = np.divide(t.T, w)
    sum_t = t.sum(axis=0)
    idf = np.log(np.divide(m, sum_t)).reshape(-1, 1)
    tf_idf = np.multiply(tf, idf)

    return tf_idf, count

def extract_top_n_words_per_topic(tf_idf, count, docs_per_topic, n=20):
    words = count.get_feature_names_out()
    labels = list(docs_per_topic.Topic)
    tf_idf_transposed = tf_idf.T
    indices = tf_idf_transposed.argsort()[:, -n:]
    top_n_words = {label: [(words[j], tf_idf_transposed[i][j]) for j in indices[i]][::-1] for i, label in enumerate(labels)}
    return top_n_words

def extract_topic_sizes(df):
    topic_sizes = (df.groupby(['Topic'])
                     .Doc
                     .count()
                     .reset_index()
                     .rename({"Topic": "Topic", "Doc": "Size"}, axis='columns')
                     .sort_values("Size", ascending=False))
    return topic_sizes

# %%
category_id = 1

# %%
tf_idf, count = c_tf_idf(topics[category_id].Doc.values, m=len(corpus))

top_n_words = extract_top_n_words_per_topic(tf_idf, count, topics[category_id], n=20)
topic_sizes = extract_topic_sizes(rslt[category_id]); topic_sizes.head(10)
# Out:
#     Topic  Size
# 0      -1  2323
# 18     17    94
# 19     18    31
# 10      9    20
# 17     16    19
# 5       4    18
# 1       0    18
# 12     11    16
# 2       1    15
# 15     14    14

# %%
top_n_words[2][:10]
# Out:
# [('이마트', 0.36454569064307263),
#  ('바이오퍼블릭', 0.3225020696614742),
#  ('브랜드', 0.2771173240786722),
#  ('건기식', 0.2687517247178952),
#  ('자체', 0.18924087601655232),
#  ('론칭', 0.17462114061749098),
#  ('오비맥주', 0.15623386741845968),
#  ('수제맥주', 0.15623386741845968),
#  ('biopublic', 0.15524917867370647),
#  ('kbc', 0.11547892570559953)]
